# %% [markdown]
# # Data Analytics Assingment No 7

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Salaries.csv')
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle       BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY     167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)     155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)     212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC       77916.0
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      134401.6
# ...                                                ...           ...
# ...

# %% [markdown]
# ### Qno1:Which employee has the highest TotalPayBenefits?

# %%
highpay = df.loc[df_copy['TotalPayBenefits'].idxmax()]
highpay
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# Benefits                                                       NaN
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %% [markdown]
# ### Qno2:Drop ID, Notes, Agency and Status Columns

# %%
df=df.drop(['Id','Notes','Agency','Status'],axis=1)
df
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#              BasePay   OvertimePay      OtherPay      Benefits   TotalPay  \
# ...

# %% [markdown]
# ### Qno3:Total Number of Job Titles Contain POLICE

# %%
df=df[df_copy.JobTitle.str.contains('POLICE',case='False')]
df
# Out:
#                   EmployeeName                                 JobTitle  \
# 1                 GARY JIMENEZ          CAPTAIN III (POLICE DEPARTMENT)
# 2               ALBERT PARDINI          CAPTAIN III (POLICE DEPARTMENT)
# 11            PATRICIA JACKSON          CAPTAIN III (POLICE DEPARTMENT)
# 15             RICHARD CORRIEA       COMMANDER III, (POLICE DEPARTMENT)
# 25                GREGORY SUHR                          CHIEF OF POLICE
# ...                        ...                                      ...
# 35131  CYNTHIA HAYNES-EPPERSON  SENIOR POLICE COMMUNICATIONS DISPATCHER
# 35151               LYNN BLOOM                     POLICE SERVICES AIDE
# 35318           ROBERT CHAPMAN                       POLICE OFFICER III
# 35671            RUSSELL MATLI                       POLICE OFFICER III
# 35902               SUSAN ROTH         SERGEANT III (POLICE DEPARTMENT)
#
#          BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# ...

# %% [markdown]
# ### Qno4:Top 10 most common job titles?

# %%
df=pd.read_csv('Salaries.csv')
common_jobs = df['JobTitle'].value_counts().head(10)
print(common_jobs)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Custodian                       2418
# TRANSIT OPERATOR                2388
# Firefighter                     2359
# Recreation Leader               1971
# Patient Care Assistant          1945
# Name: JobTitle, dtype: int64

# %% [markdown]
# ### Qno5:What are the top 10 average TotalPay by JobTitle?

# %%
df=pd.read_csv('Salaries.csv')
Avg_totalpay = df.groupby('JobTitle')['TotalPay'].mean()
top_10_jobs = Avg_totalpay.nlargest(10)
print(top_10_jobs)
# Out:
# JobTitle
# GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY    399211.275000
# Chief Investment Officer                          339653.700000
# Chief of Police                                   329183.646667
# Chief, Fire Department                            325971.683333
# DEPUTY DIRECTOR OF INVESTMENTS                    307899.460000
# CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)            302377.730000
# Gen Mgr, Public Trnsp Dept                        297769.413333
# Asst Chf of Dept (Fire Dept)                      281763.483889
# DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)      279359.560000
# Dep Dir for Investments, Ret                      278592.545000
# Name: TotalPay, dtype: float64

# %% [markdown]
# ### Qno6:How many unique job titles are there each year?

# %%
df=pd.read_csv('Salaries.csv')
unique_job = df.groupby('Year')['JobTitle'].nunique()
unique_job
# Out:
# Year
# 2011    1045
# 2012    1044
# 2013    1051
# 2014     997
# Name: JobTitle, dtype: int64

# %% [markdown]
# ### Qno7:Find Average TotalPay Of All Employee Per Year

# %%
df=pd.read_csv('Salaries.csv')
df= df.groupby('Year')['TotalPay'].mean().head(10)
df
# Out:
# Year
# 2011    71744.103871
# 2012    74113.262265
# 2013    77611.443142
# 2014    75463.918140
# Name: TotalPay, dtype: float64

# %% [markdown]
# ### Qno8:How many unique employees worked each year?

# %%
df=pd.read_csv('Salaries.csv')
df=df.groupby('Year')['EmployeeName'].nunique()
df
# Out:
# Year
# 2011    33878
# 2012    34349
# 2013    36150
# 2014    36684
# Name: EmployeeName, dtype: int64

# %% [markdown]
# ### Qno9:Which year had the most employees earning over 100,000 in TotalPay?

# %%
df=pd.read_csv('Salaries.csv')
df=df[df['TotalPay'] > 100000]['Year'].value_counts().idxmax()
df
# Out:
# 2013

# %% [markdown]
# ### Qno10:Which columns have missing values?

# %%
df=pd.read_csv('Salaries.csv')
df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                605
# OvertimePay              0
# OtherPay                 0
# Benefits             36159
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              110535
# dtype: int64
