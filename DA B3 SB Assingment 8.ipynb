# %% [markdown]
# # Assingment no 8

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('cars Company.csv')
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %% [markdown]
# ### Qno1:  Check and Drop Duplicate Records

# %%
df.shape
# Out:
# (11914, 16)

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11909    False
# 11910    False
# 11911    False
# 11912    False
# 11913    False
# Length: 11914, dtype: bool

# %%
#cheking where duplicate rows
df[df.duplicated()]
# Out:
#          Make     Model  Year             Engine Fuel Type  Engine HP  \
# 14        BMW  1 Series  2013  premium unleaded (required)      230.0
# 18       Audi       100  1992             regular unleaded      172.0
# 20       Audi       100  1992             regular unleaded      172.0
# 24       Audi       100  1993             regular unleaded      172.0
# 25       Audi       100  1993             regular unleaded      172.0
# ...       ...       ...   ...                          ...        ...
# 11481  Suzuki      X-90  1998             regular unleaded       95.0
# 11603   Volvo      XC60  2017             regular unleaded      302.0
# 11604   Volvo      XC60  2017             regular unleaded      240.0
# 11708  Suzuki       XL7  2008             regular unleaded      252.0
# 11717  Suzuki       XL7  2008             regular unleaded      252.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %%
#removing duplicated data
df=df.drop_duplicates()
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.shape #715 dupliccate rows removed
# Out:
# (11199, 16)

# %% [markdown]
# ### Qno2: Check and Drop missing or null values

# %%
#checking missing values
df.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3376
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
#dropping missing values
df.dropna(inplace=True)
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %% [markdown]
# ### Qno3:What are the top 10 average MSRP (Price) per car brand (rounded figure)? with Horizontal Bar Plot

# %%
df.rename(columns={'MSRP':'Price','Make':'Car Brand'},inplace=True )

# %%
df
# Out:
#       Car Brand       Model  Year                Engine Fuel Type  Engine HP  \
# 0           BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1           BMW    1 Series  2011     premium unleaded (required)      300.0
# 2           BMW    1 Series  2011     premium unleaded (required)      300.0
# 3           BMW    1 Series  2011     premium unleaded (required)      230.0
# 4           BMW    1 Series  2011     premium unleaded (required)      230.0
# ...         ...         ...   ...                             ...        ...
# 11909     Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910     Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911     Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912     Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913   Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.groupby('Car Brand')['Price'].mean().round().sort_values(ascending=False).head(10)
# Out:
# Car Brand
# Bugatti         1757224.0
# Maybach          546222.0
# Rolls-Royce      351131.0
# Lamborghini      331567.0
# Bentley          247169.0
# McLaren          239805.0
# Ferrari          237384.0
# Spyker           214990.0
# Aston Martin     198123.0
# Maserati         113684.0
# Name: Price, dtype: float64

# %%
#plotting result
plt.figure(figsize=(10, 6))
top_10.plot(kind='barh', color='skyblue')
plt.xlabel('Average MSRP (USD)')
plt.title('Top 10 Car Brands by Average MSRP')
plt.gca().invert_yaxis()

# %% [markdown]
# ### Qno4:How has the MSRP (price) changed over the years (rounded figure)? with Line Plot

# %%
df = df.groupby('Year')['Price'].mean().round()
df
# Out:
# Year
# 1990     2073.0
# 1991     2223.0
# 1992     2192.0
# 1993     2401.0
# 1994     2726.0
# 1995     3270.0
# 1996     3140.0
# 1997     4524.0
# 1998     4434.0
# 1999     3612.0
# 2000     3913.0
# 2001    73833.0
# 2002    55704.0
# 2003    68312.0
# 2004    55908.0
# 2005    53724.0
# 2006    39001.0
# 2007    41173.0
# 2008    80462.0
# 2009    59193.0
# 2010    60152.0
# 2011    65663.0
# 2012    71837.0
# 2013    55201.0
# 2014    71196.0
# 2015    52613.0
# 2016    52580.0
# 2017    45333.0
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(10, 6))
plt.plot(df.index, df.values, marker='o', color='green')
plt.xlabel('Year')
plt.ylabel('Average Price')
plt.title('Average Price Over the Years')
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Qno5:How Engine HP (power) and MPG (efficiency) have changed over the years? show with two line plots

# %%
df=pd.read_csv('cars Company.csv')
df
# Out:
#           Make       Model  Year                Engine Fuel Type  Engine HP  \
# 0          BMW  1 Series M  2011     premium unleaded (required)      335.0
# 1          BMW    1 Series  2011     premium unleaded (required)      300.0
# 2          BMW    1 Series  2011     premium unleaded (required)      300.0
# 3          BMW    1 Series  2011     premium unleaded (required)      230.0
# 4          BMW    1 Series  2011     premium unleaded (required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11910    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11911    Acura         ZDX  2012     premium unleaded (required)      300.0
# 11912    Acura         ZDX  2013  premium unleaded (recommended)      300.0
# 11913  Lincoln      Zephyr  2006                regular unleaded      221.0
#
# ...

# %%
df.rename(columns={'Engine HP':'Power','highway MPG':'Effiency'},inplace=True )

# %%
df = df.groupby('Year')[['Power', 'Effiency']].mean().round()

# %%
df
# Out:
#       Power  Effiency
# Year
# 1990  141.0      23.0
# 1991  148.0      22.0
# 1992  151.0      24.0
# 1993  156.0      24.0
# 1994  157.0      24.0
# 1995  175.0      23.0
# 1996  174.0      24.0
# 1997  185.0      22.0
# 1998  190.0      22.0
# 1999  189.0      23.0
# 2000  183.0      24.0
# 2001  194.0      24.0
# 2002  196.0      23.0
# 2003  206.0      23.0
# 2004  215.0      23.0
# 2005  219.0      24.0
# 2006  230.0      23.0
# 2007  252.0      22.0
# 2008  256.0      23.0
# 2009  252.0      24.0
# 2010  249.0      24.0
# 2011  263.0      25.0
# 2012  266.0      26.0
# 2013  267.0      28.0
# 2014  292.0      28.0
# 2015  271.0      29.0
# 2016  274.0      29.0
# 2017  275.0      29.0

# %%
plt.figure(figsize=(10, 6))

plt.plot(df.index, df['Power'], label='Power', marker='o', color='blue')
plt.plot(df.index, df['Effiency'], label='Effiency', marker='s', color='green')

plt.xlabel('Year')
plt.ylabel('Average Value')
plt.title('Power and Efficiency Over the Years')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Qno6: What percentage of cars are Compact, Midsize, or Large? Show with Pie chart

# %%
df=pd.read_csv('cars Company.csv')

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
percent = df['Vehicle Size'].value_counts(normalize=True).loc[['Compact', 'Midsize', 'Large']] * 100
percent.plot.pie(autopct='%.1f%%', figsize=(6, 6), title='Compact, Midsize, Large - Percentage')
# Out:
# <AxesSubplot:title={'center':'Compact, Midsize, Large - Percentage'}, ylabel='Vehicle Size'>

# %%
percent
# Out:
# Compact    39.986570
# Midsize    36.704717
# Large      23.308712
# Name: Vehicle Size, dtype: float64

# %% [markdown]
# ### Qno7:Which vehicle styles are sold the most? show with vertical bar plot

# %%
style_counts = df['Vehicle Style'].value_counts()
style_counts.plot(kind='bar', figsize=(10, 6), color='skyblue', title='Most Sold Vehicle Styles')
# Out:
# <AxesSubplot:title={'center':'Most Sold Vehicle Styles'}>

# %% [markdown]
# ### Qno8: Which car brands have the most vehicles priced at $40,000 or more and with a popularity score of at least 1000?

# %%
filtered = df[(df['MSRP'] >= 40000) & (df['Popularity'] >= 1000)]
brand_counts = filtered['Make'].value_counts()
print(brand_counts)
# Out:
# Cadillac       354
# BMW            276
# Audi           224
# Chevrolet      216
# Ford           145
# Toyota         131
# Porsche        123
# Nissan          91
# Ferrari         69
# Dodge           58
# Lamborghini     52
# Chrysler        18
# Tesla           18
# Kia             17
# Honda           14
# Hyundai         13
# Name: Make, dtype: int64
